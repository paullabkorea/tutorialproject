# %%
# 라이브러리 설치
# pip install requests
# pip install beautifulsoup4

# %% [markdown]
# ## Requests 활용

# %% [markdown]
# ### 'requests'는 HTTP 요청을 보내는데 사용하는 라이브러리

# %%
import requests

url = 'http://paullab.co.kr'
response = requests.get(url) 
print(response.headers)      # 헤더의 내용 확인
print(response.encoding)     # 인코딩 방식 확인
print(response.status_code)  # 상태코드 확인
print(response.ok)           # 정상적 접속 확인
response.encoding = 'utf-8'
print(response.text)          # html 내용 확인
# Out:
# {'Server': 'nginx', 'Date': 'Mon, 23 Mar 2020 14:32:44 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'P3P': "CP='NOI CURa ADMa DEVa TAIa OUR DELa BUS IND PHY ONL UNI COM NAV INT DEM PRE'", 'X-Powered-By': 'PHP/5.5.17p1', 'Content-Encoding': 'gzip'}
# ISO-8859-1
# 200
# True
# <!DOCTYPE html>
# <html lang="en">
#   <head>
# 	<!-- 구글 추적코드 삽입 -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=UA-143954339-1"></script>
# 	  <script>
#
#       // Global site tag (gtag.js) - Google Analytics
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-143954339-1');
#
#       // Universal Analytics tag
#   	  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   	  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# ...

# %% [markdown]
# ### 특정 페이지의 소스코드를 파일로 저장

# %%
import requests

paullab_url = "http://paullab.co.kr"
response = requests.get(paullab_url)
response.encoding = 'utf-8'
html = response.text

f = open('test.html', 'w', encoding = 'utf-8')
f.write(html)
f.close()

# %% [markdown]
# ### 특정페이지에서 특정 단어가 몇 번 언급되었는지 출력하는 코드

# %%
import requests

paullab_url = "http://paullab.co.kr"
response = requests.get(paullab_url)
response.encoding = 'utf-8'
html = response.text

splitHTML = html.split(' ')
word = input("검색할 단어를 입력하세요 : ")
print(splitHTML.count(word))
# Out:
# 검색할 단어를 입력하세요 : content
# 1

# %% [markdown]
# ## BeautifulSoup

# %% [markdown]
# ### str타입의 html 데이터를 html 구조를 가진 데이터로 가공해주는 라이브러리

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('http://paullab.co.kr')

response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')
print(soup.title)                    # title 태그 출력
print(soup.find('title'))            # title 태그 출력
print(soup.find(id=('content')))     # id가 'content'인 태그 출력

print(soup.find_all('a'))            # 모든 a 태그 출력
print(soup.select('#content'))       # id가 'content'인 모든 태그 출력
print(soup.select('.container > a')) # 'container' class 안에 모든 a 태그 출력
# Out:
# <title> Paul Lab </title>
# <title> Paul Lab </title>
# <div class="p-0" id="content">
# <!-- Features -->
# <div class="container py-4 py-lg-6" id="features">
# <hr class="hr-lg mt-0 mb-3 w-10 mx-auto hr-primary"/>
# <h2 class="text-center text-uppercase font-weight-bold my-0">
#           Core values
#         </h2>
# <h5 class="text-center font-weight-light mt-2 mb-0 text-muted">
#           Great values, great education &amp; product!
#         </h5>
# <hr class="mb-5 w-50 mx-auto"/>
# <div class="row text-center">
# <div class="col-lg-4 py-2">
# <i class="fa fa-users icon-5x text-primary" data-animate="fadeIn" data-animate-delay="0.1"></i>
# <h4 class="mt-2">Popularization</h4>
# <p>교육 특권의 대중화.</p>
# </div>
# <div class="col-lg-4 py-2">
# <i class="fa fa-line-chart icon-5x text-primary" data-animate="fadeIn" data-animate-delay="0.2"></i>
# <h4 class="mt-2">Sustainable support</h4>
# <p>학원을 그만둔 뒤에도 무료 특강, 해커톤, 서버 지원 등을 통한 원생들의 지속적인 발전 도모.</p>
# </div>
# ...

# %% [markdown]
# ### Selector
# - 태그에 좀 더 세밀한 접근이 가능
# - class를 지칭할 때는 '.'을 사용하고, id를 지칭할 때는 '#'를 사용
# - 탐색하고자 하는 태그가 특정태그 하위에 있을 때 '>'를 사용

# %% [markdown]
# ## Selector를 이용한 BeautifulsSoup 활용(1)

# %%
# 바울랩의 강의목록을 크롤링해보자.
import requests
from bs4 import BeautifulSoup

paullab_url = 'http://paullab.co.kr'
response = requests.get(paullab_url)
response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')

lecture_list = soup.select('.lecture')  # lecture 클래스 탐색
print(dir(lecture_list))
for lecture in lecture_list :
    print(lecture.text)
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort', 'source']
#
# 1. 기초부터 실무까지 Data Scientist 되기 (88,000원 / 월)
#
# 2. SW 특기자 전형 준비 (88,000원 / 월)
#
#
# 3. 풀스택 웹 개발반(구. 프로그래밍 종합반) (88,000원 / 월)
#
# 4. React native를 이용한 앱 개발 (88,000원 / 월)
#
# 5. TensorFlow 입문반 (88,000원 / 월)
#
# 6. Python 입문반 (88,000원 / 월)
#
# 7. 정보보안반 (88,000원 / 월)
#
# 8. 영재반 (88,000원 / 월)
#
#
# 🔥접수링크🔥
# https://forms.gle/5eudv8hZQjMnnDdR7
# ...

# %% [markdown]
# ## Selector를 이용한 BeautifulSoup 활용(2)

# %%
# 바울랩에서 제공하는 Book Service 목록을 크롤링해보자
import requests
from bs4 import BeautifulSoup

paullab_url = 'http://paullab.co.kr'
response = requests.get(paullab_url)
response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')

bookservices = soup.select('.col-lg-6 > h2') # col-lg-6 클래스 안의 h2 태그 탐색
for no, book in enumerate(bookservices, 1) :
    print(no, book.text)
# Out:
# 1
#                 PaulLabOrganization
